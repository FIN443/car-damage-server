# %%
import cv2
from PIL import Image

# %%
image_path = 'instance/uploads/image.jpg'

# %%
pil_img = Image.open(image_path, mode='r')
pil_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x177E14580>

# %%
cv_img = cv2.imread(image_path)[:, :, ::-1]
image = Image.fromarray(cv_img)
image
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x177E159D0>

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x105F151F0>
